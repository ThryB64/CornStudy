# %% [markdown]
# # IND-03 — Oracle analysis
#
# Variables futures volontairement connues, usage recherche uniquement.

# %% [markdown]
# ## Variables prioritaires
#
# - `oracle_wasde_ending_stocks_surprise` : delta DA +0.035, cohérence `coherent`

# %% [markdown]
# ## Résultats
#
# | oracle_var | da_without | da_with | delta_da | auc_with | priority | economic_coherence |
# |---|---|---|---|---|---|---|
# | oracle_wasde_ending_stocks_surprise | 0.570 | 0.605 | +0.035 | 0.635 | HIGH | coherent |
# | oracle_cot_mm_net_h10 | 0.471 | 0.499 | +0.028 | 0.531 | MEDIUM | coherent |
# | oracle_drought_h20 | 0.491 | 0.502 | +0.011 | 0.500 | MEDIUM | counterintuitive |
# | oracle_condition_change_h20 | 0.606 | 0.616 | +0.011 | 0.612 | MEDIUM | coherent |
# | oracle_weather_stress_h20 | 0.567 | 0.568 | +0.001 | 0.588 | LOW | coherent |
# | oracle_rain_deficit_h20 | 0.614 | 0.615 | +0.001 | 0.583 | LOW | counterintuitive |
# | oracle_heat_days_h20 | 0.567 | 0.567 | +0.000 | 0.592 | LOW | counterintuitive |
# | oracle_realized_vol_h20 | 0.567 | 0.560 | -0.007 | 0.592 | LOW | directional sign not predefined |

# %%
import pandas as pd
oracle = pd.read_parquet('../../../artefacts/professional_study/oracle_analysis.parquet')
oracle
