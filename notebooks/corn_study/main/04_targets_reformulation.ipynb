# %% [markdown]
# # 04 — Reformulation des cibles
#
# Ticket `IND-02`. Export généré depuis les artefacts vérifiés.

# %% [markdown]
# ## Cibles retenues
#
# - `y_down_gt_5pct_h20` : DA=0.841, AUC=0.707, modèle `rf_factors`
# - `y_up_gt_5pct_h20` : DA=0.807, AUC=0.599, modèle `rf_factors`
# - `y_down_gt_3pct_h10` : DA=0.799, AUC=0.664, modèle `rf_factors`

# %% [markdown]
# ## Top ranking
#
# | target | family | horizon | problem | best_model | best_da | best_auc | best_brier | delta_da_vs_seasonal | tier | decision |
# |---|---|---|---|---|---|---|---|---|---|---|
# | y_down_gt_5pct_h5 | strong_move | 5 | binary | rf_factors | 0.945 | 0.737 | 0.052 | 0.000 | Tier 1 | exploratoire — classe déséquilibrée |
# | y_up_gt_5pct_h5 | strong_move | 5 | binary | rf_factors | 0.932 | 0.640 | 0.062 | 0.000 | Tier 1 | exploratoire — classe déséquilibrée |
# | y_down_gt_5pct_h10 | strong_move | 10 | binary | rf_factors | 0.887 | 0.749 | 0.092 | -0.002 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | y_up_gt_5pct_h10 | strong_move | 10 | binary | rf_factors | 0.873 | 0.571 | 0.111 | 0.000 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | future_min_return_h30 | future_min_return | 30 | regression | ridge_factors | 0.865 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |
# | y_min_ret_h30 | future_min_return | 30 | regression | ridge_factors | 0.865 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |
# | future_min_return_h20 | future_min_return | 20 | regression | ridge_factors | 0.853 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |
# | y_min_ret_h20 | future_min_return | 20 | regression | ridge_factors | 0.853 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |
# | y_down_gt_3pct_h5 | strong_move | 5 | binary | ridge_factors | 0.847 | 0.670 | 0.124 | -0.003 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | y_down_strong_h5 | strong_move | 5 | binary | ridge_factors | 0.847 | 0.670 | 0.124 | -0.003 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | y_down_gt_5pct_h20 | strong_move | 20 | binary | rf_factors | 0.841 | 0.707 | 0.137 | 0.025 | Tier 1 | retenir pour IND-04+ |
# | y_up_gt_3pct_h5 | strong_move | 5 | binary | rf_factors | 0.829 | 0.574 | 0.141 | 0.000 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | y_up_strong_h5 | strong_move | 5 | binary | rf_factors | 0.829 | 0.574 | 0.141 | 0.000 | Tier 1 | exploratoire — ne bat pas la saisonnalité |
# | future_min_return_h10 | future_min_return | 10 | regression | ridge_factors | 0.812 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |
# | y_min_ret_h10 | future_min_return | 10 | regression | ridge_factors | 0.812 | NA | NA | NA | Tier 1 | candidat non retenu — hors cible directionnelle prioritaire |

# %%
import pandas as pd
comparison = pd.read_parquet('../../../artefacts/professional_study/target_comparison.parquet')
ranking = pd.read_csv('../../../artefacts/professional_study/target_ranking.csv')
ranking.head(20)
