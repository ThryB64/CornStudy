# %% [markdown]
# # IND-05 — Ablation et sélection de variables
#
# Analyse pré-2023, cible `y_down_gt_5pct_h20`.
#
# **Critère primaire : delta_auc** (AUC plus robuste que DA pour cible déséquilibrée, positive_rate≈21%).

# %% [markdown]
# ## Ablation familles
#
# | family | delta | da_without | da_only | vif_max | recommendation | justification |
# |---|---|---|---|---|---|---|
# | positioning | +0.010 | 0.766 | 0.786 | 1.153 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | market_volatility | -0.010 | 0.786 | 0.815 | 2.378 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | seasonality | -0.006 | 0.782 | 0.816 | 1.642 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | raw_signal | -0.012 | 0.788 | 0.810 | 1.300 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | crop_condition | +0.001 | 0.775 | 0.790 | 1.544 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | drought_severity | +0.002 | 0.774 | 0.765 | 1.006 | NEUTRE | delta AUC proche de zéro |
# | export_demand | +0.000 | 0.776 | 0.816 | inf | NEUTRE | delta AUC neutre mais colinéarité élevée |
# | weather_belt_stress | -0.018 | 0.795 | 0.814 | 1.612 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | ethanol_demand | +0.002 | 0.774 | 0.787 | 1.526 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | wasde_supply_demand | -0.003 | 0.779 | 0.815 | 1.318 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | macro_dollar_rates | -0.042 | 0.818 | 0.785 | 1.338 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | market_momentum | -0.014 | 0.790 | 0.818 | 3.905 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | cross_commodity | -0.026 | 0.802 | 0.815 | 2.378 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |

# %% [markdown]
# ## Feature selection
#
# | family | delta | da_only | vif_max | recommendation | justification |
# |---|---|---|---|---|---|
# | positioning | +0.010 | 0.786 | 1.153 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | market_volatility | -0.010 | 0.815 | 2.378 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | seasonality | -0.006 | 0.816 | 1.642 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | raw_signal | -0.012 | 0.810 | 1.300 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | crop_condition | +0.001 | 0.790 | 1.544 | GARDER | retrait dégrade l'AUC, famille utile (delta_auc > 0) |
# | drought_severity | +0.002 | 0.765 | 1.006 | NEUTRE | delta AUC proche de zéro |
# | export_demand | +0.000 | 0.816 | inf | NEUTRE | delta AUC neutre mais colinéarité élevée |
# | weather_belt_stress | -0.018 | 0.814 | 1.612 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | ethanol_demand | +0.002 | 0.787 | 1.526 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | wasde_supply_demand | -0.003 | 0.815 | 1.318 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | macro_dollar_rates | -0.042 | 0.785 | 1.338 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | market_momentum | -0.014 | 0.818 | 3.905 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |
# | cross_commodity | -0.026 | 0.815 | 2.378 | RETIRER | retrait améliore l'AUC, famille potentiellement bruitée (delta_auc < 0) |

# %%
import pandas as pd
ablation = pd.read_parquet('../../../artefacts/professional_study/ablation_results.parquet')
selection = pd.read_parquet('../../../artefacts/professional_study/feature_selection.parquet')
ablation, selection
